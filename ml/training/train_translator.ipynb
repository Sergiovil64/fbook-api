# %% [markdown]
# # Entrenamiento del traductor ES->EN (PLACEHOLDER)
#
# Guía para el integrante de ML. Entrena/afina un modelo de traducción por redes neuronales
# (seq2seq / transformer, ej. MarianMT o mBART) ES->EN y lo despliega en el endpoint
# `fbook-translator`.
#
# El modelo debe respetar el contrato de `../CONTRACT.md` (sección 1):
# `in {"text": "..."}` -> `out {"text": "<english>", "srcLang": "es"|"en"}`.
# La **detección de idioma** vive en este endpoint: si el texto ya esta en ingles, devolverlo
# intacto con `srcLang='en'`.

# %%
import sagemaker, boto3

session = sagemaker.Session()
role = sagemaker.get_execution_role()
account = boto3.client('sts').get_caller_identity()['Account']

BUCKET = f'fbook-ml-{account}'
MODEL_S3 = f's3://{BUCKET}/models/translator/'
ENDPOINT = 'fbook-translator'
print(BUCKET)

# %%
# TODO(ML): preparar corpus paralelo ES-EN, afinar el modelo de traduccion,
#           empaquetar model.tar.gz y subir a MODEL_S3.
# TODO(ML): el inference handler debe: detectar idioma -> traducir si es 'es' ->
#           responder {text, srcLang} segun ../CONTRACT.md.
raise NotImplementedError('Placeholder: implementar entrenamiento/despliegue del traductor')
